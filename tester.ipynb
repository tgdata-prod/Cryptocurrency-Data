# %%
from test_api import write_api_execution_data, load_api_execution_data, get_university_data_http

# %%
req = get_university_data_http(http_params={'school.name': 'Harvard University', "fields": "id,school.name,latest.student.size",\
                                      'per_page': 20})

# %%
meta_data = load_api_execution_data()

# %%
write_api_execution_data(meta_data)

# %%
meta_data
# Out:
# {'last_execution_time': '2025-11-18T12:54:47.099041', 'api_call_count': 0}

# %%
print(datetime.now().isoformat())
# Out:
# 2025-11-18T12:46:55.086866
