# %%
from test_api import write_api_execution_data, load_api_execution_data, get_university_data_http
import json
from datetime import datetime, timedelta
import pytz

# %%
api_execution_data = load_api_execution_data()
print(api_execution_data)
# Out:
# {'last_execution_time_utc': '2025-11-24T02:55:02.414439+00:00', 'api_call_count': 1}

# %%
http_params = {'school.name': 'Harvard University', "fields": "id,school.name,latest.student.size",'per_page': 20}
data, meta_data = get_university_data_http(http_params, api_execution_data)
# Out:
# commencing fetch
#
# page is 1 total pages is 1
#  ---------------------------
# all pages cycled
# last executed {'last_execution_time_utc': '2025-11-24T02:55:47.005129+00:00', 'api_call_count': 2}
# time in mins until refresh 59.28306893333333
